# %%
a = 20
b = 300000
c = 75000

hasil = (a * b) + (a * c)
print('maka pengeluaran gaji + asuransi Rp :'+ str(hasil))
print('')
a = 14
b = 360000
c = 75000

hasil = (a * b) + (a * c)
print('maka pengeluaran gaji + asuransi Rp :'+ str(hasil))

print('')
a = 28
b = 475000
c = 75000

hasil = (a * b) + (a * c)
print('maka pengeluaran gaji + asuransi Rp :'+ str(hasil))

print('')
a = 42
b = 580000
c = 75000

hasil = (a * b) + (a * c)
print('maka pengeluaran gaji + asuransi Rp :'+ str(hasil))

print('')
a = 18
b = 400000
c = 75000

hasil = (a * b) + (a * c)
print('maka pengeluaran gaji + asuransi Rp :'+ str(hasil))
# Out:
# maka pengeluaran gaji + asuransi Rp :7500000
#
# maka pengeluaran gaji + asuransi Rp :6090000
#
# maka pengeluaran gaji + asuransi Rp :15400000
#
# maka pengeluaran gaji + asuransi Rp :27510000
#
# maka pengeluaran gaji + asuransi Rp :8550000

# %%
print('======soal no 2======')
pajak = 0.03
laba_a = 32500000
laba_b = 31000000
laba_c = 42000000
laba_d = 51500000
laba_e = 27000000
aset_a = 0.08
aset_b = 0.04
aset_c = 0.12
aset_d = 0.11
aset_e = 0.03

hasil = (laba_a * pajak) + (aset_a * 280000000)
print('maka total pajak dan utang adalah Rp :' + str(hasil))

print('')
hasil = (laba_b * pajak) + (aset_b * 310000000)
print('maka total pajak dan utang adalah Rp :' + str(hasil))
print('')
hasil = (laba_c * pajak) + (aset_c * 420000000)
print('maka total pajak dan utang adalah Rp :' + str(hasil))
print('')
hasil = (laba_d * pajak) + (aset_d * 550000000)
print('maka total pajak dan utang adalah Rp :' + str(hasil))
print('')
hasil = (laba_e * pajak) + (aset_e * 340000000)
print('maka total pajak dan utang adalah Rp :' + str(hasil))

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("DATA PICART")
makanan = ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon', ]
jml = [23375000.0, 13330000.0, 51660000.0, 62045000.0,11010000.0]
ax.pie(jml,labels=makanan,autopct='%1.2f%%')
plt.show()

print('')
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ekskul = ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon', ]
mengikuti =[23375000.0, 13330000.0, 51660000.0, 62045000.0,11010000.0]
c = 'black', 'pink', 'blue'
plt.title("DATA BAR")
plt.bar(ekskul, mengikuti, color = c)
plt.grid(True)
plt.show()
# Out:
# ======soal no 2======
# maka total pajak dan utang adalah Rp :23375000.0
#
# maka total pajak dan utang adalah Rp :13330000.0
#
# maka total pajak dan utang adalah Rp :51660000.0
#
# maka total pajak dan utang adalah Rp :62045000.0
#
# maka total pajak dan utang adalah Rp :11010000.0

# %%
import matplotlib.pyplot as plt

# %%
print('=====soal no 3======')
csr1 = 0.025
csr2 = 0.035
aset1 = 280000000
aset1 = 310000000
aset1 = 420000000
aset1 = 550000000
aset1 = 340000000

hasil = (csr1 * 280000000)
print('maka CSR perusahaan a adalah : Rp' + str(hasil))
hasil = (csr2 * 310000000)
print('maka CSR perusahaan a adalah : Rp' + str(hasil))
hasil = (csr2 * 420000000)
print('maka CSR perusahaan a adalah : Rp' + str(hasil))
hasil = (csr2 * 550000000)
print('maka CSR perusahaan a adalah : Rp' + str(hasil))
hasil = (csr2 * 340000000)
print('maka CSR perusahaan a adalah : Rp' + str(hasil))

print('')
print('')
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("DATA PICART")
makanan = ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon', ]
jml = [7000000.0, 10850000.000000002, 14700000.000000002, 19250000.0, 11900000.000000002 ]
ax.pie(jml,labels=makanan,autopct='%1.2f%%')
plt.show()
print('')
print('')
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ekskul = ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon', ]
mengikuti = [7000000.0, 10850000.000000002, 14700000.000000002, 19250000.0, 11900000.000000002 ] 
c = 'black', 'pink', 'blue'
plt.title("DATA BAR")
plt.bar(ekskul, mengikuti, color = c)
plt.grid(True)
plt.show()
# Out:
# =====soal no 3======
# maka CSR perusahaan a adalah : Rp7000000.0
# maka CSR perusahaan a adalah : Rp10850000.000000002
# maka CSR perusahaan a adalah : Rp14700000.000000002
# maka CSR perusahaan a adalah : Rp19250000.0
# maka CSR perusahaan a adalah : Rp11900000.000000002

# %%
laba_1 = 32500000
laba_2 = 31000000
laba_3 = 42000000
laba_4 = 51500000
laba_5 = 27000000

hasil1 = (laba_1 * 12)
print('totalaba perusahaan a ' + str(hasil))

hasil2 = (laba_2 * 12)
print('totalaba perusahaan b ' + str(hasil))

hasil3 = (laba_3 * 12)
print('totalaba perusahaan c ' + str(hasil))

hasil4 = (laba_4 * 12)
print('totalaba perusahaan d ' + str(hasil))

hasil5 = (laba_5 * 12)
print('totalaba perusahaan e ' + str(hasil))

hasil6 = hasil1 + hasil2 + hasil3 + hasil4 + hasil5
print('total laba semua perusahaa selama 1 tahun Rp :' + str(hasil6))
# Out:
# totalaba perusahaan a 11900000.000000002
# totalaba perusahaan b 11900000.000000002
# totalaba perusahaan c 11900000.000000002
# totalaba perusahaan d 11900000.000000002
# totalaba perusahaan e 11900000.000000002
# total laba semua perusahaa selama 1 tahun Rp :2208000000

# %%
laba_f = 32500000
laba_g = 31000000
laba_h = 42000000
laba_i = 51500000
laba_j = 27000000
tahun = 12
AXis =20
BLog =14
Cin  = 28
DNamic = 42
Epsilon = 18
csr1 = 0.025
csr2 = 0.035
aset1 = 280000000
aset2 = 310000000
aset3 = 420000000
aset4 = 550000000
aset5 = 340000000

hasil_1 = (32500000 * 12 ) - 0.025 * 280000000 - (7500000 * 12) - 23375000.0
print("total pendapatan perusahaan e : Rp" + str(hasil_1))

hasil_2 = (laba_g * tahun ) - csr2 * 310000000 - (6090000 * tahun) - 13330000.0
print("total pendapatan perusahaan e : Rp" + str(hasil_2))

hasil_3 = (laba_h * tahun ) - csr2 * aset3 - (15400000 * tahun) - 51660000.0
print("total pendapatan perusahaan e : Rp" + str(hasil_3))

hasil_4  = (laba_i * tahun ) - csr2 * aset4 - (27510000 * tahun) - 62045000.0
print("total pendapatan perusahaan e : Rp" + str(hasil_4))

hasil_5 = (laba_j * tahun ) - csr2 * aset5 - (8550000 * tahun) - 11010000.0

print("total pendapatan perusahaan e : Rp" + str(hasil_5))

print('')
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("DATA PICART")
makanan = ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon', ]
jml = [269625000.0, 274740000.0, 252840000.0, 206585000.0, 198490000.0 ]
ax.pie(jml,labels=makanan,autopct='%1.2f%%')
plt.show()
print('')
print('')
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ekskul = ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon', ]
mengikuti = [269625000.0, 274740000.0, 252840000.0, 206585000.0, 198490000.0 ] 
c = 'black', 'pink', 'blue'
plt.title("DATA BAR")
plt.bar(ekskul, mengikuti, color = c)
plt.grid(True)
plt.show()
# Out:
# total pendapatan perusahaan e : Rp269625000.0
# total pendapatan perusahaan e : Rp274740000.0
# total pendapatan perusahaan e : Rp252840000.0
# total pendapatan perusahaan e : Rp206585000.0
# total pendapatan perusahaan e : Rp198490000.0
