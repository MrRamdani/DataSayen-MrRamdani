# %%
print ("====NUMBER 1=====")
a = 0
b = 1
c = 4
d = 7
e = 5
f = 0

hasil = (a + b) + (c + d) + (e + f)

print ("maka jumlah orang tingkatan s2 = " + str(hasil))

a = 4
b = 12
c = 6
d = 13
e = 14
f = 0

hasil = (a + b) + (c + d) + (e + f)

print ("maka jumlah orang tingkatan s1 = " + str(hasil))
a = 12
b = 17
c = 5
d = 20
e = 11
f = 75

hasil = (a + b) + (c + d) + (e + f)

print ("maka jumlah orang tamat SMA = " + str(hasil))

a = 5
b = 6
c = 15
d = 9
e = 20
f = 15

hasil = (a + b) + (c + d) + (e + f)

print ("maka jumlah orang tamat smp = " + str(hasil))


a = 1
b = 8
c = 0
d = 19
e = 10
f = 1

hasil = (a + b) + (c + d) + (e + f)

print ("maka jumlah orang tamat sd = " + str(hasil))

a = 2
b = 14
c = 3
d = 10
e = 0
f = 1

hasil = (a + b) + (c + d) + (e + f)

print ("maka jumlah orang yang tidak di ketahui = " + str(hasil))


print ("====NUMBER 2=====")

a = 17
b = 0.25
hasil = (a * b)
print ("maka mutu pendidikan s2 adalah = " + str(hasil))

a = 49
b = 0.20
hasil = (a * b)
print ("maka mutu pendidikan s1 adalah = " + str(hasil))

a = 140
b = 0.15
hasil = (a * b)
print ("maka mutu pendidikan SMA adalah = " + str(hasil))

a = 70
b = 0.10
hasil = (a * b)
print ("maka mutu pendidikan SMP adalah = " + str(hasil))

a = 39
b = 0.5
hasil = (a * b)
print ("maka mutu pendidikan SD adalah = " + str(hasil))

a = 30
b = 0.3
hasil = (a * b)
print ("maka mutu pendidikan TDK adalah = " + str(hasil))

print ("====NUMBER 3=====")
a = 0
b = 0.25
hasil = (a * b)
print ("maka mutu pendidikan S2 adalah = " + str(hasil))
c = 4
d = 0.20
hasil = (c * d )
print ("maka mutu pendidikan S1 adalah = " + str(hasil))
e = 12
f = 0.15
hasil = (e * f )
print ("maka mutu pendidikan SMA adalah = " + str(hasil))
g = 5
h = 0.10
hasil = (g * h )
print ("maka mutu pendidikan SMP adalah = " + str(hasil))
i = 1
j = 0.5
hasil = (i * j )
print ("maka mutu pendidikan SD adalah = " + str(hasil))
k = 2
l = 0.3
hasil = (k * l) 
print ("maka mutu pendidikan TDK adalah = " + str(hasil))

hasil = (0.0 + 0.8) + (1.7 + 0.5) + (0.5 + 0.6) + (25)
print ("indeks mutu rentang usia >70= " + str(hasil))

#kedua
a = 1
b = 0.25
hasil = (a * b)
print ("maka mutu pendidikan S2 adalah = " + str(hasil))
c = 12
d = 0.20
hasil = (c * d )
print ("maka mutu pendidikan S1 adalah = " + str(hasil))
e = 17
f = 0.15
hasil = (e * f )
print ("maka mutu pendidikan SMA adalah = " + str(hasil))
g = 6
h = 0.10
hasil = (g * h )
print ("maka mutu pendidikan SMP adalah = " + str(hasil))
i = 8
j = 0.5
hasil = (i * j )
print ("maka mutu pendidikan SD adalah = " + str(hasil))
k = 14
l = 0.3
hasil = (k * l) 
print ("maka mutu pendidikan TDK adalah = " + str(hasil))

hasil = (0.25 + 2.4) + (2.55 + 0.6) + (2.0 + 4.2)
print ("indeks mutu rentang usia >60= " + str(hasil))

#ketiga
a = 4
b = 0.25
hasil = (a * b)
print ("maka mutu pendidikan S2 adalah = " + str(hasil))
c = 6
d = 0.20
hasil = (c * d )
print ("maka mutu pendidikan S1 adalah = " + str(hasil))
e = 5
f = 0.15
hasil = (e * f )
print ("maka mutu pendidikan SMA adalah = " + str(hasil))
g = 15
h = 0.10
hasil = (g * h )
print ("maka mutu pendidikan SMP adalah = " + str(hasil))
i = 1
j = 0.5
hasil = (i * j )
print ("maka mutu pendidikan SD adalah = " + str(hasil))
k = 2
l = 0.3
hasil = (k * l) 
print ("maka mutu pendidikan TDK adalah = " + str(hasil))

hasil = (1.0 + 1.2) + (0.75 + 1.5) + (0.5 + 0.6)
print ("indeks mutu rentang usia >50= " + str(hasil))

a = 7
b = 0.25
hasil = (a * b)
print ("maka mutu pendidikan S2 adalah = " + str(hasil))
c = 13
d = 0.20
hasil = (c * d )
print ("maka mutu pendidikan S1 adalah = " + str(hasil))
e = 20
f = 0.15
hasil = (e * f )
print ("maka mutu pendidikan SMA adalah = " + str(hasil))
g = 9
h = 0.10
hasil = (g * h )
print ("maka mutu pendidikan SMP adalah = " + str(hasil))
i = 19
j = 0.5
hasil = (i * j )
print ("maka mutu pendidikan SD adalah = " + str(hasil))
k = 10
l = 0.3
hasil = (k * l) 
print ("maka mutu pendidikan TDK adalah = " + str(hasil))

hasil = (1.75 + 2.6) + (3.0 + 0.9) + (9.5 + 3.0) 
print ("indeks mutu rentang usia >40= " + str(hasil))
a = 5
b = 0.25
hasil = (a * b)
print ("maka mutu pendidikan S2 adalah = " + str(hasil))
c = 14
d = 0.20
hasil = (c * d )
print ("maka mutu pendidikan S1 adalah = " + str(hasil))
e = 11
f = 0.15
hasil = (e * f )
print ("maka mutu pendidikan SMA adalah = " + str(hasil))
g = 20
h = 0.10
hasil = (g * h )
print ("maka mutu pendidikan SMP adalah = " + str(hasil))
i = 10
j = 0.5
hasil = (i * j )
print ("maka mutu pendidikan SD adalah = " + str(hasil))
k = 0
l = 0.3
hasil = (k * l) 
print ("maka mutu pendidikan TDK adalah = " + str(hasil))

hasil = (1.25 + 2.8) + (1.65 + 2.0) + (5.0 + 0.0)
print ("indeks mutu rentang usia >30= " + str(hasil))
a = 0
b = 0.25
hasil = (a * b)
print ("maka mutu pendidikan S2 adalah = " + str(hasil))
c = 0
d = 0.20
hasil = (c * d )
print ("maka mutu pendidikan S1 adalah = " + str(hasil))
e = 75
f = 0.15
hasil = (e * f )
print ("maka mutu pendidikan SMA adalah = " + str(hasil))
g = 15
h = 0.10
hasil = (g * h )
print ("maka mutu pendidikan SMP adalah = " + str(hasil))
i = 1
j = 0.5
hasil = (i * j )
print ("maka mutu pendidikan SD adalah = " + str(hasil))
k = 1
l = 0.3
hasil = (k * l) 
print ("maka mutu pendidikan TDK adalah = " + str(hasil))

hasil = (0.0 + 0.0) + (0.0 + 0.0) + (11.25 + 1.5) + (0.5 + 0.3)
print ("indeks mutu rentang usia >20= " + str(hasil))

print("===SOAL 4====")
min = [0.6000000000000001]
print("MAKA PADA USIA >70. " + str(min))
# Out:
# ====NUMBER 1=====
# maka jumlah orang tingkatan s2 = 17
# maka jumlah orang tingkatan s1 = 49
# maka jumlah orang tamat SMA = 140
# maka jumlah orang tamat smp = 70
# maka jumlah orang tamat sd = 39
# maka jumlah orang yang tidak di ketahui = 30
# ====NUMBER 2=====
# maka mutu pendidikan s2 adalah = 4.25
# maka mutu pendidikan s1 adalah = 9.8
# maka mutu pendidikan SMA adalah = 21.0
# maka mutu pendidikan SMP adalah = 7.0
# maka mutu pendidikan SD adalah = 19.5
# maka mutu pendidikan TDK adalah = 9.0
# ====NUMBER 3=====
# maka mutu pendidikan S2 adalah = 0.0
# maka mutu pendidikan S1 adalah = 0.8
# maka mutu pendidikan SMA adalah = 1.7999999999999998
# maka mutu pendidikan SMP adalah = 0.5
# maka mutu pendidikan SD adalah = 0.5
# maka mutu pendidikan TDK adalah = 0.6
# indeks mutu rentang usia >70= 29.1
# maka mutu pendidikan S2 adalah = 0.25
# maka mutu pendidikan S1 adalah = 2.4000000000000004
# maka mutu pendidikan SMA adalah = 2.55
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['S2', 'S1', 'SMA', 'SMP', 'SD', 'TDK' ]
hasil = [17, 49, 140, 70, 39, 30]
c = 'black', 'pink', 'blue'
plt.title("PENDIDIKAN")
plt.bar(pendidikan, hasil, color = c)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usia = ['70', '60', '50', '40', '30', '20' ]
hasil = [29.1, 12.0, 5.550000000000001, 20.75, 12.7, 13.55]
c = 'black', 'pink', 'blue'
plt.title("usia")
plt.bar(usia, hasil, color = c)
plt.show()

# %%
#pie cahrt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("pendidikan")
pendidikan = ['S2', 'S1', 'SMA', 'SMP', 'SD', 'TDK' ]
hasil = [17, 49, 140, 70, 39, 30]
ax.pie(hasil,labels=pendidikan,autopct='%1.2f%%')
plt.show()

#pie cahrt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("usia")
usia = ['70', '60', '50', '40', '30', '20' ]
hasil = [29.1, 12.0, 5.550000000000001, 20.75, 12.7, 13.55]
ax.pie(hasil,labels=usia,autopct='%1.2f%%')
plt.show()
